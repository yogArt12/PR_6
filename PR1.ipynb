# %%
pip install wordcloud

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt

# %%
f = open("Pidatato_Kenegaraan_Indonesia.txt", "r")

isi_text = f.read()

# %%
print(isi_text)
# Out:
# Yang saya hormatiWakil Presiden Republik Indonesia Bapak Prof Dr KH Maruf Amin beserta Ibu Wurry Estu Maruf Amin
# ...

# %%
wordcloud = WordCloud(width=1600, height=800, max_font_size=200, background_color='white')

# %%
wordcloud.generate(isi_text)

# %%
plt.figure(figsize=(12,10))

plt.imshow(wordcloud, interpolation='bilinear')

plt.axis("off")

plt.show()
